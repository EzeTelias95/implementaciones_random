# %%
from LRU_Cache import lru_cache_impl


@lru_cache_impl(2)
def suma(a: int, b: int):
    return a+b

suma(a=1, b=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       4 @lru_cache_impl(2)
#       5 def suma(a: int, b: int):
#       6     return a+b
# ----> 8 suma(a=1, b=2)
#
# TypeError: update_wrapper() got an unexpected keyword argument 'a'
